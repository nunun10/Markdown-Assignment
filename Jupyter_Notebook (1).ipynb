# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# My name is **LHINGNUNCHING L** <br>
# I am currently a Post Graduate Student

# %% [markdown]
# _I am interested in data science because it is a very interesting subject which combines my passion for graphical designing, coding and statistics. <br> Data science has a lot of scope and is required in every single industry and I am passionate about being a part of the social benefits that data scientists can bring._

# %% [markdown]
# ### The code in the cell below prints the current year.

# %%
import datetime
now = datetime.datetime.now()

print(now.year)
# Out:
# 2022

# %% [markdown]
# Random Facts about me: <br>
# I love ~~vegateblis~~ vegetables. My favorites include
# - potato
# - capsicum
# - beans <br>
#
# My favorite TV show is `Modern Family`
# Here is a picture: <br> ![image.png](attachment:a038bb08-c73f-4c36-8879-d2749b9d169b.png)
#
# > I love Data Science.
#
# Some of my favorite artists are:
# 1. Rod Stewart
# 2. Bon Jovi
# 3. Guns n' Roses
#
# <hr/>
# Thank You.
